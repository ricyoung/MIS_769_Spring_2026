# %% [markdown]
# # 🤖 Homework 10: Business Agent
# **MIS 769 - Big Data Analytics for Business | Spring 2026**
#
# **Points:** 20 | **Due:** See WebCampus for deadline
#
# **Author:** Richard Young, Ph.D. | UNLV Lee Business School
#
# **Compute:** CPU (free tier) — Uses OpenRouter API (no local GPU needed)
#
# ---
#
# ## What You'll Learn
#
# 1. What AI agents are and how they work
# 2. Build an agent that uses **native tool calling** via an LLM API
# 3. Design tools as **JSON schemas** — the industry standard
# 4. Implement the ReAct (Reasoning + Acting) pattern
# 5. Observe an LLM **autonomously** deciding which tools to use and when
#
# ---

# %% [markdown]
# ## What You're About to Build
#
# Below is the **complete agent loop** you'll implement. Read through it before running — understand the flow, then watch it work.
#
# ```python
# def call_llm(messages, tools=None, retries=3):
#     """Call the LLM with automatic retry on rate-limit (429) errors."""
#     for attempt in range(retries):
#         try:
#             kwargs = {"model": MODEL, "messages": messages}
#             if tools:
#                 kwargs["tools"] = tools
#                 kwargs["tool_choice"] = "auto"
#             return client.chat.completions.create(**kwargs)
#         except Exception as e:
#             if "429" in str(e) and attempt < retries - 1:
#                 wait = 10 * (attempt + 1)
#                 time.sleep(wait)
#             else:
#                 raise
#
# def run_agent(task, max_steps=10):
#     messages = [system_prompt, {"role": "user", "content": task}]
#     for step in range(max_steps):
#         response = call_llm(messages, tools=TOOL_SCHEMAS)
#         msg = response.choices[0].message
#
#         if msg.tool_calls:             # Model wants to use a tool
#             messages.append(msg)       # Save assistant message first
#             for tc in msg.tool_calls:
#                 result = TOOL_FUNCTIONS[tc.function.name](**args)
#                 messages.append({"role": "tool", "tool_call_id": tc.id, "content": result})
#
#         elif finish == "stop":         # Model gives final text answer
#             return msg.content
# ```
#
# Key points:
# - **`call_llm()`** wraps the API call with retry logic for rate limits
# - **`tool_choice="auto"`** lets the model decide when to use tools
# - The assistant message with `tool_calls` must be appended **before** the tool results
# - Each tool result needs the matching `tool_call_id`
# - The loop continues until the model gives a text answer or we hit `max_steps`
#
# ---

# %% [markdown]
# ## How Modern Tool Calling Works
#
# In production AI systems (OpenAI, Anthropic, Google, OpenRouter), tool calling follows a **structured JSON protocol** — not string parsing.
#
# ### The Old Way (String Parsing) :x:
# ```python
# # Model outputs raw text: "USE search_products(laptop)"
# # You parse it with regex to extract the tool name and arguments
# # Fragile, error-prone, breaks easily
# ```
#
# ### The Modern Way (JSON Tool Calling) :white_check_mark:
# ```python
# # You define tools as JSON schemas (name, description, parameters)
# # Model returns structured JSON: {"name": "search_products", "arguments": {"query": "laptop"}}
# # You execute the function and return the result as a tool message
# # Reliable, typed, industry standard
# ```
#
# ### The Protocol
#
# ```
# Step 1: You send -> messages + tool definitions (JSON schemas)
# Step 2: Model returns -> tool_calls: [{name: "search_products", arguments: {query: "laptop"}}]
# Step 3: You execute -> result = search_products("laptop")
# Step 4: You send back -> tool result message (role: "tool")
# Step 5: Model either -> calls more tools OR gives final text answer
# ```
#
# This is the **exact same pattern** used by ChatGPT plugins, Claude's tool use, and Gemini function calling. Learning it once transfers everywhere.
#
# ### What We're Using
#
# | Component | Choice | Why |
# |-----------|--------|-----|
# | **LLM API** | [OpenRouter](https://openrouter.ai) | Unified API for 200+ models, OpenAI-compatible |
# | **Model** | Qwen 2.5 7B Instruct | Cheap ($0.04/M tokens), reliable tool calling |
# | **SDK** | `openai` Python library | Industry standard, works with OpenRouter |
# | **Tools** | JSON function schemas | Same format as OpenAI/Anthropic/Google |
#
# ---

# %% [markdown]
# ## Part 1: Agent Setup (3 points)

# %%
# !pip install openai -q

# ── Fix Jupyter emoji bug ──────────────────────────────────────
# Some Colab/Jupyter versions crash on emoji in print output.
# This patches the serializer to use ASCII-safe JSON encoding.
import jupyter_client.session as _jcs
import json as _json

def _safe_json_packer(obj, default=_jcs.json_default):
    return _json.dumps(
        obj, default=default, ensure_ascii=True, allow_nan=False
    ).encode("utf-8")

_jcs.json_packer = _safe_json_packer
del _jcs, _json, _safe_json_packer

import json
import os
import re
import time
from openai import OpenAI

# ── API Key Setup ──────────────────────────────────────────────
# Option A: Google Colab secrets (recommended on Colab)
# 1. Click the key icon in Colab's left sidebar
# 2. Add a secret named OPENROUTER_API_KEY with your key
# Option B: Environment variable (works locally)
# Option C: Manual input (works anywhere)
OPENROUTER_API_KEY = None

try:
    from google.colab import userdata
    OPENROUTER_API_KEY = userdata.get("OPENROUTER_API_KEY")
    print("API key loaded from Colab secrets")
except Exception:
    pass

if not OPENROUTER_API_KEY:
    OPENROUTER_API_KEY = os.environ.get("OPENROUTER_API_KEY")
    if OPENROUTER_API_KEY:
        print("API key loaded from environment variable")

if not OPENROUTER_API_KEY:
    import getpass
    OPENROUTER_API_KEY = getpass.getpass("Enter your OpenRouter API key: ")
    print("API key entered manually")

# ── OpenRouter Client ──────────────────────────────────────────
# OpenRouter uses the same API format as OpenAI, just a different base URL
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=OPENROUTER_API_KEY,
)

# ── Model Selection ────────────────────────────────────────────
# Recommended: cheap + reliable (entire homework costs ~$0.01)
MODEL = "qwen/qwen-2.5-7b-instruct"       # $0.04/M in, $0.10/M out

# Free alternatives (may rate-limit at 8 req/min):
# MODEL = "qwen/qwen3-next-80b-a3b-instruct:free"
# MODEL = "qwen/qwen3-coder:free"
# MODEL = "qwen/qwen3-4b:free"

print(f"OpenRouter client ready  (model: {MODEL})")
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3.14 -m pip install --upgrade pip
# API key loaded from environment variable
# OpenRouter client ready  (model: qwen/qwen-2.5-7b-instruct)

# %%
# Test the connection with a simple message (no tools)
test = client.chat.completions.create(
    model=MODEL,
    messages=[{"role": "user", "content": "Say hello in exactly 5 words."}],
    max_tokens=50,
)

# Clean up any <think> tags from Qwen 3 models
response_text = test.choices[0].message.content or ""
response_text = response_text.encode("utf-8", errors="replace").decode("utf-8")
response_text = re.sub(r"<think>.*?</think>", "", response_text, flags=re.DOTALL).strip()

print("CONNECTION TEST")
print("=" * 60)
print(f"Model: {MODEL}")
print(f"Response: {response_text}")
print(f"Tokens used: {test.usage.total_tokens}")
# Out:
# CONNECTION TEST
# ...
# Model: qwen/qwen-2.5-7b-instruct
# Response: Good to see you.
# Tokens used: 4042

# %% [markdown]
# ## Part 2: Tool Design (5 points)
#
# An agent is only as useful as its tools. We need:
#
# 1. **Business data** — A product catalog and order database
# 2. **Tool functions** — Python functions that query the data
# 3. **Tool schemas** — JSON descriptions so the LLM knows what’s available
#
# The LLM never sees the raw data. It can only access it through the tools you provide.

# %%
import pandas as pd

# ── Product Catalog ────────────────────────────────────────────
products = pd.DataFrame([
    {"product_id": "LP001", "name": 'TechPro Laptop 15"', "price": 899.99, "stock": 15, "category": "Laptops", "rating": 4.5, "description": "15-inch laptop, 16GB RAM, 512GB SSD, Intel i7"},
    {"product_id": "LP002", "name": 'UltraBook Pro 14"', "price": 649.99, "stock": 23, "category": "Laptops", "rating": 4.2, "description": "Lightweight 14-inch ultrabook, 8GB RAM, 256GB SSD"},
    {"product_id": "LP003", "name": 'GamerMax 17"', "price": 1299.99, "stock": 8, "category": "Laptops", "rating": 4.7, "description": "17-inch gaming laptop, RTX 4060, 32GB RAM, 1TB SSD"},
    {"product_id": "LP004", "name": 'BudgetBook 15"', "price": 399.99, "stock": 42, "category": "Laptops", "rating": 3.8, "description": "Affordable 15-inch laptop, 4GB RAM, 128GB SSD"},
    {"product_id": "PH001", "name": "SmartPhone X", "price": 799.99, "stock": 45, "category": "Phones", "rating": 4.6, "description": "6.1-inch OLED, 128GB, 48MP camera"},
    {"product_id": "PH002", "name": "SmartPhone SE", "price": 429.99, "stock": 60, "category": "Phones", "rating": 4.3, "description": "5.4-inch compact phone, 64GB, great battery"},
    {"product_id": "PH003", "name": "SmartPhone Ultra", "price": 1199.99, "stock": 12, "category": "Phones", "rating": 4.8, "description": "6.7-inch AMOLED, 256GB, 200MP camera, S-Pen"},
    {"product_id": "AC001", "name": "Wireless Earbuds Pro", "price": 129.99, "stock": 100, "category": "Accessories", "rating": 4.4, "description": "Active noise cancellation, 24hr battery"},
    {"product_id": "AC002", "name": "Bluetooth Speaker", "price": 79.99, "stock": 75, "category": "Accessories", "rating": 4.1, "description": "Waterproof portable speaker, 12hr battery"},
    {"product_id": "AC003", "name": "USB-C Hub 7-in-1", "price": 49.99, "stock": 150, "category": "Accessories", "rating": 4.3, "description": "HDMI, USB-A, SD card, ethernet adapter"},
    {"product_id": "AC004", "name": "Laptop Stand Aluminum", "price": 34.99, "stock": 200, "category": "Accessories", "rating": 4.6, "description": "Ergonomic adjustable aluminum laptop stand"},
    {"product_id": "MN001", "name": 'UltraWide Monitor 34"', "price": 549.99, "stock": 18, "category": "Monitors", "rating": 4.7, "description": "34-inch curved ultrawide, 3440x1440, 144Hz"},
    {"product_id": "MN002", "name": '4K Monitor 27"', "price": 349.99, "stock": 30, "category": "Monitors", "rating": 4.5, "description": "27-inch 4K IPS panel, 60Hz, USB-C"},
    {"product_id": "MN003", "name": 'Gaming Monitor 27"', "price": 299.99, "stock": 25, "category": "Monitors", "rating": 4.4, "description": "27-inch 1080p, 240Hz, 1ms response time"},
    {"product_id": "TB001", "name": 'ProTab 11"', "price": 599.99, "stock": 35, "category": "Tablets", "rating": 4.6, "description": "11-inch tablet with stylus support, 128GB"},
    {"product_id": "TB002", "name": 'ProTab Mini 8"', "price": 349.99, "stock": 50, "category": "Tablets", "rating": 4.3, "description": "Compact 8-inch tablet, 64GB, great for reading"},
    {"product_id": "NW001", "name": "WiFi 6 Router", "price": 149.99, "stock": 40, "category": "Networking", "rating": 4.2, "description": "Dual-band WiFi 6 router, covers 2500 sq ft"},
    {"product_id": "NW002", "name": "Mesh WiFi System 3-Pack", "price": 279.99, "stock": 22, "category": "Networking", "rating": 4.5, "description": "Whole-home mesh WiFi, covers 5000 sq ft"},
])

# ── Order History ──────────────────────────────────────────────
orders = pd.DataFrame([
    {"order_id": "ORD001", "product_id": "LP001", "customer": "Alice Johnson", "status": "shipped", "quantity": 1, "date": "2026-02-10"},
    {"order_id": "ORD002", "product_id": "PH001", "customer": "Bob Smith", "status": "processing", "quantity": 1, "date": "2026-02-15"},
    {"order_id": "ORD003", "product_id": "AC001", "customer": "Carol Davis", "status": "delivered", "quantity": 2, "date": "2026-02-01"},
    {"order_id": "ORD004", "product_id": "MN001", "customer": "David Wilson", "status": "shipped", "quantity": 1, "date": "2026-02-12"},
    {"order_id": "ORD005", "product_id": "LP003", "customer": "Eve Martinez", "status": "processing", "quantity": 1, "date": "2026-02-16"},
    {"order_id": "ORD006", "product_id": "AC003", "customer": "Frank Lee", "status": "delivered", "quantity": 3, "date": "2026-01-28"},
    {"order_id": "ORD007", "product_id": "TB001", "customer": "Grace Kim", "status": "cancelled", "quantity": 1, "date": "2026-02-14"},
])

print("BUSINESS ENVIRONMENT")
print("=" * 60)
print(f"Products: {len(products)} across {products['category'].nunique()} categories")
print(f"Categories: {', '.join(products['category'].unique())}")
print(f"Price range: ${products['price'].min():.2f} - ${products['price'].max():.2f}")
print(f"Orders: {len(orders)}")
print()
products[['product_id', 'name', 'price', 'stock', 'category', 'rating']].head(10)
# Out:
# BUSINESS ENVIRONMENT
# ...
# Products: 18 across 6 categories
# Categories: Laptops, Phones, Accessories, Monitors, Tablets, Networking
# Price range: $34.99 - $1299.99
# Orders: 7
#   product_id                  name    price  stock     category  rating
# 0      LP001    TechPro Laptop 15"   899.99     15      Laptops     4.5
# 1      LP002     UltraBook Pro 14"   649.99     23      Laptops     4.2
# 2      LP003          GamerMax 17"  1299.99      8      Laptops     4.7
# 3      LP004        BudgetBook 15"   399.99     42      Laptops     3.8
# 4      PH001          SmartPhone X   799.99     45       Phones     4.6
# 5      PH002         SmartPhone SE   429.99     60       Phones     4.3
# 6      PH003      SmartPhone Ultra  1199.99     12       Phones     4.8
# 7      AC001  Wireless Earbuds Pro   129.99    100  Accessories     4.4
# 8      AC002     Bluetooth Speaker    79.99     75  Accessories     4.1
# 9      AC003      USB-C Hub 7-in-1    49.99    150  Accessories     4.3

# %%
# ── Tool Functions ─────────────────────────────────────────────
# Each tool returns a JSON string (the standard for tool results)

def search_products(query):
    """Search products by name or category."""
    q = query.lower()
    mask = (
        products["name"].str.lower().str.contains(q, na=False)
        | products["category"].str.lower().str.contains(q, na=False)
        | products["description"].str.lower().str.contains(q, na=False)
    )
    matches = products[mask][["product_id", "name", "price", "category", "rating"]]
    if matches.empty:
        return json.dumps({"results": [], "message": f"No products matching '{query}'"})
    return matches.to_json(orient="records")


def get_product_details(product_id):
    """Get full details for a product by its ID."""
    match = products[products["product_id"] == product_id]
    if match.empty:
        return json.dumps({"error": f"Product '{product_id}' not found"})
    return match.iloc[0].to_json()


def filter_by_price(min_price, max_price):
    """Find products within a price range."""
    mask = (products["price"] >= min_price) & (products["price"] <= max_price)
    matches = products[mask][["product_id", "name", "price", "category", "rating"]]
    matches = matches.sort_values("price")
    if matches.empty:
        return json.dumps({"results": [], "message": f"No products between ${min_price} and ${max_price}"})
    return matches.to_json(orient="records")


def get_order_status(order_id):
    """Look up the status of a customer order."""
    match = orders[orders["order_id"] == order_id]
    if match.empty:
        return json.dumps({"error": f"Order '{order_id}' not found"})
    row = match.iloc[0]
    product = products[products["product_id"] == row["product_id"]]
    product_name = product.iloc[0]["name"] if not product.empty else "Unknown"
    return json.dumps({
        "order_id": row["order_id"],
        "customer": row["customer"],
        "product": product_name,
        "status": row["status"],
        "quantity": int(row["quantity"]),
        "date": row["date"],
    })


def check_stock(product_id):
    """Check inventory stock level for a product."""
    match = products[products["product_id"] == product_id]
    if match.empty:
        return json.dumps({"error": f"Product '{product_id}' not found"})
    row = match.iloc[0]
    return json.dumps({
        "product_id": product_id,
        "name": row["name"],
        "stock": int(row["stock"]),
        "in_stock": int(row["stock"]) > 0,
    })


# Registry: map function names to callables
TOOL_FUNCTIONS = {
    "search_products": search_products,
    "get_product_details": get_product_details,
    "filter_by_price": filter_by_price,
    "get_order_status": get_order_status,
    "check_stock": check_stock,
}

print("AVAILABLE TOOLS")
print("=" * 60)
for name, func in TOOL_FUNCTIONS.items():
    print(f"  - {name}: {func.__doc__}")
# Out:
# AVAILABLE TOOLS
# ...
#   - search_products: Search products by name or category.
#   - get_product_details: Get full details for a product by its ID.
#   - filter_by_price: Find products within a price range.
#   - get_order_status: Look up the status of a customer order.
#   - check_stock: Check inventory stock level for a product.

# %%
# ── Tool Schemas (JSON) ────────────────────────────────────────
# These tell the LLM what tools exist, what they do, and what
# parameters they accept. This is the INDUSTRY STANDARD format
# used by OpenAI, Anthropic, Google, and OpenRouter.

TOOL_SCHEMAS = [
    {
        "type": "function",
        "function": {
            "name": "search_products",
            "description": "Search for products by name, category, or keyword. Returns matching products with ID, name, price, category, and rating.",
            "parameters": {
                "type": "object",
                "properties": {
                    "query": {
                        "type": "string",
                        "description": "Search term (e.g., 'laptop', 'monitors', 'wireless')"
                    }
                },
                "required": ["query"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "get_product_details",
            "description": "Get full details for a specific product including description, price, stock, and rating.",
            "parameters": {
                "type": "object",
                "properties": {
                    "product_id": {
                        "type": "string",
                        "description": "Product ID (e.g., 'LP001', 'PH002', 'AC003')"
                    }
                },
                "required": ["product_id"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "filter_by_price",
            "description": "Find all products within a price range, sorted by price ascending.",
            "parameters": {
                "type": "object",
                "properties": {
                    "min_price": {
                        "type": "number",
                        "description": "Minimum price in dollars"
                    },
                    "max_price": {
                        "type": "number",
                        "description": "Maximum price in dollars"
                    }
                },
                "required": ["min_price", "max_price"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "get_order_status",
            "description": "Look up a customer order by order ID. Returns status, product, customer, and date.",
            "parameters": {
                "type": "object",
                "properties": {
                    "order_id": {
                        "type": "string",
                        "description": "Order ID (e.g., 'ORD001')"
                    }
                },
                "required": ["order_id"]
            }
        }
    },
    {
        "type": "function",
        "function": {
            "name": "check_stock",
            "description": "Check current inventory stock level for a product.",
            "parameters": {
                "type": "object",
                "properties": {
                    "product_id": {
                        "type": "string",
                        "description": "Product ID (e.g., 'LP001')"
                    }
                },
                "required": ["product_id"]
            }
        }
    }
]

print(f"\u2705 {len(TOOL_SCHEMAS)} tool schemas defined")
print()
# Preview one schema
print("Example schema (search_products):")
print(json.dumps(TOOL_SCHEMAS[0], indent=2))
# Out:
# ✅ 5 tool schemas defined
#
# Example schema (search_products):
# {
#   "type": "function",
#   "function": {
#     "name": "search_products",
#     "description": "Search for products by name, category, or keyword. Returns matching products with ID, name, price, category, and rating.",
#     "parameters": {
#       "type": "object",
#       "properties": {
#         "query": {
#           "type": "string",
#           "description": "Search term (e.g., 'laptop', 'monitors', 'wireless')"
#         }
#       },
#       "required": [
#         "query"
#       ]
#     }
#   }
# }

# %%
# ── Test Tools Manually ────────────────────────────────────────
print("TOOL TESTS")
print("=" * 60)

print("\nsearch_products('laptop'):")
print(search_products("laptop"))

print("\nget_product_details('PH001'):")
print(get_product_details("PH001"))

print("\nfilter_by_price(100, 300):")
print(filter_by_price(100, 300))

print("\nget_order_status('ORD001'):")
print(get_order_status("ORD001"))

print("\ncheck_stock('LP003'):")
print(check_stock("LP003"))
# Out:
# TOOL TESTS
# ...
#
# search_products('laptop'):
# [{"product_id":"LP001","name":"TechPro Laptop 15\"","price":899.99,"category":"Laptops","rating":4.5},{"product_id":"LP002","name":"UltraBook Pro 14\"","price":649.99,"category":"Laptops","rating":4.2},{"product_id":"LP003","name":"GamerMax 17\"","price":1299.99,"category":"Laptops","rating":4.7},{"product_id":"LP004","name":"BudgetBook 15\"","price":399.99,"category":"Laptops","rating":3.8},{"product_id":"AC004","name":"Laptop Stand Aluminum","price":34.99,"category":"Accessories","rating":4.6}]
#
# get_product_details('PH001'):
# {"product_id":"PH001","name":"SmartPhone X","price":799.99,"stock":45,"category":"Phones","rating":4.6,"description":"6.1-inch OLED, 128GB, 48MP camera"}
#
# filter_by_price(100, 300):
# ...

# %% [markdown]
# ## Part 3: ReAct Agent Loop (5 points)
#
# Now we build the **agent loop** — the core of the system. Here’s what happens on each turn:
#
# 1. **Send** the conversation history + tool schemas to the LLM
# 2. **Check** the response:
#    - If the model returns `tool_calls` → execute each tool, append results, loop back to step 1
#    - If the model returns a text `stop` → that’s the final answer
# 3. **Repeat** until the model gives a final answer or we hit max steps
#
# The LLM **autonomously decides** which tools to call and in what order. We just execute what it asks for and feed the results back.
#
# ### Key Implementation Details
#
# - The assistant’s message (with `tool_calls`) must be appended to history **before** the tool results
# - Each tool result must include the `tool_call_id` that matches the request
# - The message role for tool results is `"tool"` (not `"function"` or `"assistant"`)
# - Qwen 3 models may include `<think>...</think>` reasoning tags — we strip these from the final output

# %%
def strip_think_tags(text):
    """Remove <think>...</think> reasoning tags from Qwen 3 output."""
    if not text:
        return text
    text = text.encode("utf-8", errors="replace").decode("utf-8")
    return re.sub(r"<think>.*?</think>", "", text, flags=re.DOTALL).strip()


def safe_str(text):
    """Sanitize a string so it can be printed safely in Jupyter."""
    if not text:
        return text or ""
    return text.encode("utf-8", errors="replace").decode("utf-8")


def call_llm(messages, tools=None, retries=3):
    """Call the LLM with automatic retry on rate-limit (429) errors."""
    for attempt in range(retries):
        try:
            kwargs = {"model": MODEL, "messages": messages}
            if tools:
                kwargs["tools"] = tools
                kwargs["tool_choice"] = "auto"
            return client.chat.completions.create(**kwargs)
        except Exception as e:
            if "429" in str(e) and attempt < retries - 1:
                wait = 10 * (attempt + 1)
                print(f"   Rate limited, waiting {wait}s...")
                time.sleep(wait)
            else:
                raise


def run_agent(task, max_steps=10):
    """
    Run the business agent using the ReAct pattern with tool calling.

    The agent loop:
    1. Send messages + tool schemas to the LLM
    2. If model returns tool_calls -> execute tools, feed results back
    3. If model returns text (stop) -> return final answer
    4. Repeat until done or max_steps reached
    """
    print(f"TASK: {task}")
    print("=" * 60)

    messages = [
        {
            "role": "system",
            "content": (
                "You are a helpful business assistant for an electronics store. "
                "Use the provided tools to look up product information, check "
                "inventory, and track orders. Always use tools to get real data "
                "before answering -- never guess. When you have enough information, "
                "provide a clear, helpful final answer to the customer."
            ),
        },
        {"role": "user", "content": task},
    ]

    for step in range(max_steps):
        response = call_llm(messages, tools=TOOL_SCHEMAS)

        msg = response.choices[0].message
        finish = response.choices[0].finish_reason

        # -- Model wants to call tools --
        if msg.tool_calls:
            messages.append(msg)

            for tc in msg.tool_calls:
                func_name = tc.function.name
                func_args = json.loads(tc.function.arguments)

                print(f"\nACTION: {func_name}({safe_str(json.dumps(func_args))})")

                if func_name in TOOL_FUNCTIONS:
                    result = TOOL_FUNCTIONS[func_name](**func_args)
                else:
                    result = json.dumps({"error": f"Unknown tool: {func_name}"})

                print(f"OBSERVATION: {safe_str(result[:200])}{'...' if len(result) > 200 else ''}")

                messages.append({
                    "role": "tool",
                    "tool_call_id": tc.id,
                    "content": result,
                })

        # -- Model gives final answer --
        elif finish == "stop":
            answer = strip_think_tags(msg.content)
            print(f"\nFINAL ANSWER:\n{answer}")
            return answer

        # -- Unexpected state --
        else:
            if msg.content:
                messages.append({"role": "assistant", "content": safe_str(msg.content)})

    print("\nMax steps reached without a final answer.")
    return "Agent could not complete the task."


print("Agent loop ready")
# Out:
# Agent loop ready

# %%
# Run the agent on a product search task
run_agent("Find the cheapest laptop in stock and tell me about it.")
# Out:
# TASK: Find the cheapest laptop in stock and tell me about it.
# ...
# ACTION: get_product_details({"product_id": "A315-24P"})
# OBSERVATION: {"error": "Product 'A315-24P' not found"}
# ACTION: search_products({"query": "laptop"})
# OBSERVATION: [{"product_id":"LP001","name":"TechPro Laptop 15\"","price":899.99,"category":"Laptops","rating":4.5},{"product_id":"LP002","name":"UltraBook Pro 14\"","price":649.99,"category":"Laptops","rating":4.2...
# FINAL ANSWER:
# Based on the real-time inventory data, the cheapest laptop available is the "BudgetBook 15\"", which has a price of $399.99. Here are some details about it:
#
# - **Name**: BudgetBook 15"
# - **Price**: $399.99
# - **Category**: Laptops
# - **Rating**: 3.8
#
# This laptop might be a good budget option as it has received good reviews but the rating indicates it's not the top tier in terms of performance or features. If you need more details or specifications about this laptop, please let me know!
#
# ...

# %% [markdown]
# ## Part 4: Business Tasks (5 points)
#
# Now test the agent on realistic business scenarios. Watch how it **autonomously decides** which tools to call and in what order.
#
# Notice the **ReAct pattern** in action:
# - The model **reasons** about what information it needs
# - It **acts** by calling the appropriate tool
# - It **observes** the result and decides what to do next
# - It **repeats** until it has enough information to answer

# %%
# Scenario 1: Order tracking
print("\n" + "=" * 60)
run_agent("What is the status of order ORD002? Who placed it and what did they order?")
# Out:
# ...
# TASK: What is the status of order ORD002? Who placed it and what did they order?
# ...
# ACTION: get_order_status({"order_id": "ORD002"})
# OBSERVATION: {"order_id": "ORD002", "customer": "Bob Smith", "product": "SmartPhone X", "status": "processing", "quantity": 1, "date": "2026-02-15"}
# FINAL ANSWER:
# The status of order ORD002 is currently processing. It was placed by Bob Smith and they ordered one SmartPhone X.
# 'The status of order ORD002 is currently processing. It was placed by Bob Smith and they ordered one SmartPhone X.'

# %%
# Scenario 2: Price comparison (requires multiple tool calls)
print("\n" + "=" * 60)
run_agent("I have a budget of $500. What monitors can I get? Which one do you recommend?")
# Out:
# ...
# TASK: I have a budget of $500. What monitors can I get? Which one do you recommend?
# ...
# ACTION: search_products({"query": "monitors under $500"})
# OBSERVATION: {"results": [], "message": "No products matching 'monitors under $500'"}
# FINAL ANSWER:
# It looks like there are no monitors available at exactly $500, but we can certainly help you find some great options within that price range!
#
# Based on the recent reviews and tests, here are some of the top budget monitors that are highly recommended:
#
# 1. **BenQ GW2486TC**:
#    - Pros: Ergonomic stand, good contrast ratio, full sRGB color coverage, generous port selection, 100Hz refresh rate.
#    - Cons: Modest resolution and brightness, awkward OSD control buttons.
#    - Price: $169.99 - $199.99 (you can get it cheaper at times)
#
# 2. **Philips 221V8LB**:
#    - Pros: Exceptional value, ultra-high contrast ratio, full sRGB color coverage, 100Hz refresh rate and adaptive sync.
#    - Cons: Limited port selection, small size.
# ...

# %%
# Scenario 3: Complex multi-step query
print("\n" + "=" * 60)
run_agent(
    "I need to set up a home office. I want a laptop, a monitor, and a laptop stand. "
    "Find me options and tell me the total cost of a good mid-range setup."
)
# Out:
# ...
# TASK: I need to set up a home office. I want a laptop, a monitor, and a laptop stand. Find me options and tell me the total cost of a good mid-range setup.
# ...
# ACTION: get_product_details({"product_id": "BasicPerformanceDesktopOrLaptop"})
# OBSERVATION: {"error": "Product 'BasicPerformanceDesktopOrLaptop' not found"}
# ACTION: search_products({"query": "laptop mid-range"})
# OBSERVATION: {"results": [], "message": "No products matching 'laptop mid-range'"}
# ACTION: search_products({"query": "monitor mid-range"})
# OBSERVATION: {"results": [], "message": "No products matching 'monitor mid-range'"}
# ACTION: search_products({"query": "laptop stand mid-range"})
# OBSERVATION: {"results": [], "message": "No products matching 'laptop stand mid-range'"}
# ACTION: filter_by_price({"max_price": 500, "min_price": 300})
# ...

# %% [markdown]
# ## Interactive Agent Demo
#
# Type any question below and click **Ask Agent** (or press Enter) to watch the agent reason through it step by step. Try questions that require multiple tools:
#
# - *"Compare the two cheapest phones and check if both are in stock"*
# - *"What's the most expensive item we sell? How many are left?"*
# - *"I want a tablet and earbuds for under $750 total. What are my options?"*
# - *"Look up order ORD004 and tell me about the product that was ordered"*

# %%
import ipywidgets as widgets
from IPython.display import display, HTML

# ── Visual agent runner (shows each step with color) ───────────
def run_agent_visual(task, output_area, max_steps=10):
    """Run agent and render each step as styled HTML inside output_area."""
    lines = []
    lines.append(f"<h4 style='margin:4px 0'>TASK: {task}</h4><hr>")

    messages = [
        {
            "role": "system",
            "content": (
                "You are a helpful business assistant for an electronics store. "
                "Use the provided tools to look up product information, check "
                "inventory, and track orders. Always use tools to get real data "
                "before answering -- never guess. When you have enough information, "
                "provide a clear, helpful final answer to the customer."
            ),
        },
        {"role": "user", "content": task},
    ]

    step_num = 0
    for step in range(max_steps):
        response = call_llm(messages, tools=TOOL_SCHEMAS)
        msg = response.choices[0].message
        finish = response.choices[0].finish_reason

        if msg.tool_calls:
            messages.append(msg)
            for tc in msg.tool_calls:
                step_num += 1
                func_name = tc.function.name
                func_args = json.loads(tc.function.arguments)
                args_str = safe_str(json.dumps(func_args))

                if func_name in TOOL_FUNCTIONS:
                    result = TOOL_FUNCTIONS[func_name](**func_args)
                else:
                    result = json.dumps({"error": f"Unknown tool: {func_name}"})

                # Truncate long observations for display
                display_result = safe_str(result[:300])
                if len(result) > 300:
                    display_result += "..."

                lines.append(
                    f"<div style='margin:6px 0;padding:8px;background:#f0f4ff;"
                    f"border-left:4px solid #4a90d9;border-radius:4px;font-family:monospace'>"
                    f"<b>Step {step_num} &mdash; {func_name}</b>"
                    f"<br><span style='color:#555'>Args:</span> "
                    f"<code>{args_str}</code>"
                    f"<br><span style='color:#555'>Result:</span> "
                    f"<code style='word-break:break-all'>{display_result}</code>"
                    f"</div>"
                )

                messages.append({
                    "role": "tool",
                    "tool_call_id": tc.id,
                    "content": result,
                })

            # Live-update the output after each round of tool calls
            with output_area:
                output_area.clear_output(wait=True)
                display(HTML("".join(lines) + "<p><i>Thinking...</i></p>"))

        elif finish == "stop":
            answer = strip_think_tags(msg.content) or "(no answer)"
            answer_html = safe_str(answer).replace("\n", "<br>")
            lines.append(
                f"<div style='margin:10px 0;padding:10px;background:#e8f5e9;"
                f"border-left:4px solid #43a047;border-radius:4px'>"
                f"<b>FINAL ANSWER</b> (after {step_num} tool call{'s' if step_num != 1 else ''})"
                f"<br><br>{answer_html}</div>"
            )
            with output_area:
                output_area.clear_output(wait=True)
                display(HTML("".join(lines)))
            return
        else:
            if msg.content:
                messages.append({"role": "assistant", "content": safe_str(msg.content)})

    lines.append("<div style='color:orange'><b>Max steps reached.</b></div>")
    with output_area:
        output_area.clear_output(wait=True)
        display(HTML("".join(lines)))


# ── Build the widget UI ───────────────────────────────────────
text_input = widgets.Text(
    value="",
    placeholder="Ask the agent anything about our store...",
    layout=widgets.Layout(width="75%", height="36px"),
)
run_button = widgets.Button(
    description=" Ask Agent",
    button_style="primary",
    layout=widgets.Layout(width="120px", height="36px"),
)
output_area = widgets.Output(
    layout=widgets.Layout(
        border="1px solid #ddd",
        min_height="80px",
        max_height="600px",
        overflow_y="auto",
        padding="8px",
        margin="8px 0 0 0",
    )
)

def on_submit(_):
    question = text_input.value.strip()
    if not question:
        return
    with output_area:
        output_area.clear_output(wait=True)
        display(HTML("<p><i>Sending to agent...</i></p>"))
    run_agent_visual(question, output_area)

run_button.on_click(on_submit)
text_input.on_submit(on_submit)  # Enter key also triggers

display(widgets.HBox([text_input, run_button]))
display(output_area)
# Out:
# /var/folders/17/_mtgn6ks4dzg0z3p7njpy3y00000gn/T/ipykernel_99765/3299421560.py:125: DeprecationWarning: on_submit is deprecated. Instead, set the .continuous_update attribute to False and observe the value changing with: mywidget.observe(callback, 'value').
#   text_input.on_submit(on_submit)  # Enter key also triggers
# ...
# Output(layout=Layout(border_bottom='1px solid #ddd', border_left='1px solid #ddd', border_right='1px solid #dd…

# %% [markdown]
# ---
#
# ## Questions to Answer
#
# **Q1:** Describe your agent’s tools. Why did you choose them?
#
# *Your answer:*
#
# **Q2:** Walk through one complete agent trace. What worked well?
#
# *Your answer:*
#
# **Q3:** When did the agent fail? How would you improve it?
#
# *Your answer:*
#
# **Q4:** How could this agent save time in a real business?
#
# *Your answer:*

# %% [markdown]
# ---
#
# ## Submission Checklist
#
# | Item | Points | Done? |
# |------|--------|-------|
# | Part 1: Agent setup (OpenRouter + Qwen) | 3 | :white_large_square: |
# | Part 2: Tool design (JSON schemas + functions) | 5 | :white_large_square: |
# | Part 3: ReAct agent loop | 5 | :white_large_square: |
# | Part 4: Business tasks (3 scenarios) | 5 | :white_large_square: |
# | Interactive demo | 2 | :white_large_square: |
# | **Total** | **20** | |
