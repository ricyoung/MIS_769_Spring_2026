# %% [markdown]
# # Analyze Me #1 — Text Data Exploration
# **MIS 769 Big Data Analytics | Spring 2026**
#
# ---
#
# **Your Name:**
# **Dataset:**
# **Date:**

# %% [markdown]
# ## Section 1: The Problem
# What question are you trying to answer? Why does this topic matter? Even one sentence is fine — just give me the "why."
#
# Then find a text dataset and load it here. This could come from Kaggle, HuggingFace, a public API, web scraping, or anywhere else.
#
# - What is your question or problem?
# - What dataset did you find? Where did it come from?
# - How big is it (rows, columns, file size)?

# %%
# Load your dataset here
# Examples:
#   import pandas as pd
#   df = pd.read_csv('your_data.csv')
#
#   from datasets import load_dataset
#   ds = load_dataset('dataset_name')

# %% [markdown]
# ## Section 2: Explore & Understand
# Get to know your data before doing anything fancy. Look at the shape, columns, sample rows, and basic statistics.

# %%
# Explore your data
# df.shape, df.head(), df.describe(), df.info(), etc.

# %% [markdown]
# ## Section 3: Clean & Preprocess
# Real data is messy. What did you have to fix — **and why?**
#
# Don't just say "I removed stopwords." Tell me *why* you removed them and what difference it made.
#
# - Missing values? Duplicates? Encoding issues?
# - Tokenization, lowercasing, stopword removal?
# - **Why did you make these choices? What changed?**

# %%
# Clean and preprocess your text data

# %% [markdown]
# ## Section 4: Analyze & Visualize
# This is the core of your work. Apply NLP techniques and create visualizations.
#
# Ideas: word frequency, word clouds, sentiment analysis, named entity recognition, topic modeling, n-grams, text length distributions...

# %%
# Your analysis and visualizations

# %% [markdown]
# ## Section 5: Conclusion
# Tie it all together. Go back to your original question from Section 1.
#
# - **Did the data answer your question?** What did you find?
# - What patterns or surprises emerged?
# - What would you investigate next if you had more time?
# - How would you explain this to a non-technical person?

# %% [markdown]
# *Write your findings here...*
