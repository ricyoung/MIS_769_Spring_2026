# %% [markdown]
# # Install htop for CPU Monitoring
#
# Run this cell, then open Terminal (click + button → Terminal) and type `htop`

# %%
# !apt update -qq && apt install -y htop
print("\n✓ htop installed! Open Terminal and run: htop")
